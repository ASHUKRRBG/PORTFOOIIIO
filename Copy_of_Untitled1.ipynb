# %% [markdown]
# <a href="https://colab.research.google.com/github/ASHUKRRBG/PORTFOOIIIO/blob/main/Copy_of_Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("python")
# Out:
# python

# %%
print("python"+"programming")
# Out:
# pythonprogramming

# %%
print("python" + "programming")
# Out:
# pythonprogramming

# %% [markdown]
# Basic Data type for  python programming
# 1. int
# 2. Float
# 3. Str

# %%
type(8)
# Out:
# int

# %%
type(5.3)
# Out:
# float

# %%
type("Enlgish")
# Out:
# str

# %%
number_1 = int(input("enter the first number :"))
number_2 = int(input("enter the second number :"))
mul = number_1 * number_2
print(mul)
# Out:
# enter the first number :5
# enter the second number :5
# 25

# %%
from ast import Sub
number_1 = int(input("enter the first number :"))
number_2 = int(input("enter the second number :"))
div = number_1 / number_2
print(div)
# Out:
# enter the first number :25
# enter the second number :5
# 5.0

# %%
def add_number(*args):
  return sum(args)
  result = add_numbers(1,2,3,4,5)
  print(f"sum of numbers (1,2,3,4,5): {result}")
  result_two = add_numbers(10,20,30)
  print(f"sum of numbers (10,20,30): {result_two}")
  result_three = add_numbers(7)
  print(f"sum of numbers (7): {result_three}")

# %% [markdown]
# COMPARISION OPERATOR

# %%
a= 5
b=10
print(a == b)
print( a != b)
print(a > b)
print(a < b)
print(a >= b)
print(a <= b)
# Out:
# False
# True
# False
# True
# False
# True

# %% [markdown]
# SPECIAL DATA TYPES
# TYPES OF OBJECTS IN PYTHON
# 1. IMMUTABLE OBJECTS  - MEANS CHANGEABLE
# 2. MMUTABLE OBJECTS - MEAND UNCHANGABLE
#
# *   List item
# *   List item

# %%
from typing import MutableMapping
from io import StringIO
IMMUTABLE OBJECTS
1.Int
2.FLOAT
3. String
4. boolean_
5. Tuple
Mutable
1.List
2. Set
3. DICTIONARY

# %%
my_list =[1,2,3,4,5]
print(my_list)
type(my_list)
# Out:
# [1, 2, 3, 4, 5]
# list

# %%
my_list = [1,2,2.5,"english", True]
print(my_list)
# Out:
# [1, 2, 2.5, 'english', True]

# %% [markdown]
# tuple

# %%
tuple_1 = (2,3,4,5,6)
print(tuple_1)
type(tuple_1)
# Out:
# (2, 3, 4, 5, 6)
# tuple
